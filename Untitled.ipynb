# %%
import sagemaker
ss = sagemaker.Session()
role = sagemaker.get_execution_role()
print (role)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# arn:aws:iam::088199345311:role/SandboxServiceRole

# %%
import boto3
import logging


br_client = boto3.client('bedrock-agent-runtime')

response = br_client.retrieve(
    knowledgeBaseId='5JDOP0XO5B',
    retrievalConfiguration={
        'vectorSearchConfiguration': {
            'numberOfResults': 50
#            'overrideSearchType': 'HYBRID'
        }
    },
    retrievalQuery={
        'text': 'htmlunit 3.8.0'
    }
)

print(response)
# Out:
# {'ResponseMetadata': {'RequestId': '44e6b68c-ca11-4474-9efc-34a037628d13', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Wed, 10 Apr 2024 15:54:38 GMT', 'content-type': 'application/json', 'content-length': '52987', 'connection': 'keep-alive', 'x-amzn-requestid': '44e6b68c-ca11-4474-9efc-34a037628d13'}, 'RetryAttempts': 0}, 'retrievalResults': [{'content': {'text': '================ Name: CVE-2023-26119 Status: Candidate Reference: MISC:https://github.com/HtmlUnit/htmlunit/commit/641325bbc84702dc9800ec7037aec061ce21956b Reference: URL:https://github.com/HtmlUnit/htmlunit/commit/641325bbc84702dc9800ec7037aec061ce21956b Reference: MISC:https://security.snyk.io/vuln/SNYK-JAVA-NETSOURCEFORGEHTMLUNIT-3252500 Reference: URL:https://security.snyk.io/vuln/SNYK-JAVA-NETSOURCEFORGEHTMLUNIT-3252500 Reference: MISC:https://siebene.github.io/2022/12/30/HtmlUnit-RCE/ Reference: URL:https://siebene.github.io/2022/12/30/HtmlUnit-RCE/  Versions of the package net.sourceforge.htmlunit:htmlunit from 0 and before 3.0.0 are vulnerable to Remote Code Execution (RCE) via XSTL, when browsing the attacker&#8217;s webpage.  ====================================================== Name: CVE-2023-2612 Status: Candidate Reference:'}, 'location': {'type': 'S3', 's3Location': {'uri': 's3://gen-ai-pom-cve/cve-2020/cve_chunk_al.txt'}}, 'score': 0.57877314}, {'content': {'text': '======================================== Name: CVE-2020-5529 Status: Candidate Reference: CONFIRM:https://github.com/HtmlUnit/htmlunit/releases/tag/2.37.0 Reference: JVN:https://jvn.jp/en/jp/JVN34535327/ Reference: URL:https://jvn.jp/en/jp/JVN34535327/ Reference: MLIST:[camel-commits] 20200520 [camel] branch camel-2.25.x updated: Updating htmlunit due to CVE-2020-5529 Reference: URL:https://lists.apache.org/thread.html/ra2cd7f8e61dc6b8a2d9065094cd1f46aa63ad10f237ee363e26e8563@%3Ccommits.camel.apache.org%3E Reference: MLIST:[debian-lts-announce] 20200815 [SECURITY] [DLA 2326-1] htmlunit security update Reference: URL:https://lists.debian.org/debian-lts-announce/2020/08/msg00023.html Reference: UBUNTU:USN-4584-1 Reference: URL:https://usn.ubuntu.com/4584-1/  HtmlUnit prior to 2.37.0 contains code execution vulnerabilities. HtmlUnit initializes Rhino engine improperly, hence a malicious JavScript code can execute arbitrary Java code on the application. Moreover, when embedded in Android application'}, 'location': {'type': 'S3', 's3Location': {'uri': 's3://gen-ai-pom-cve/cve-2020/cve_chunk_aj.txt'}}, 'score': 0.57769996}, {'content': {'text': 'Affected Products: IGSS Data Server(IGSSdataServer.exe)(V16.0.0.23040 and prior), IGSS Dashboard(DashBoard.exe)(V16.0.0.23040 and prior), Custom Reports(RMS16.dll)(V16.0.0.23040 and prior).  ====================================================== Name: CVE-2023-2798 Status: Candidate Reference: MISC:https://bugs.chromium.org/p/oss-fuzz/issues/detail?id=54613 Reference: URL:https://bugs.chromium.org/p/oss-fuzz/issues/detail?id=54613 Reference: MISC:https://github.com/HtmlUnit/htmlunit/commit/940dc7fd Reference: URL:https://github.com/HtmlUnit/htmlunit/commit/940dc7fd  Those using HtmlUnit to browse untrusted webpages may be vulnerable to Denial of service attacks (DoS). If HtmlUnit is running on user supplied web pages, an attacker may supply content that causes HtmlUnit to crash by a stack overflow.'}, 'location': {'type': 'S3', 's3Location': {'uri': 's3://gen-ai-pom-cve/cve-2020/cve_chunk_al.txt'}}, 'score': 0.5626695}, {'content': {'text': 'An attacker may be able to use that information to recover the key. There is currently no fix available. As a workaround, avoid using the RSA crate in settings where attackers are able to observe timing information, e.g. local use on a non-compromised computer.  ====================================================== Name: CVE-2023-49093 Status: Candidate Reference: MISC:https://github.com/HtmlUnit/htmlunit/security/advisories/GHSA-37vq-hr2f-g7h7 Reference: URL:https://github.com/HtmlUnit/htmlunit/security/adviso ...
